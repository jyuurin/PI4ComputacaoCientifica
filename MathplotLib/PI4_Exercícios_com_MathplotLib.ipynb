# %% [markdown]
# <a href="https://colab.research.google.com/github/jyuurin/MathplotLib/blob/main/PI4_Exerc%C3%ADcios_com_MathplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

mes = np.arange(12) + 1 # meses de 1 a 12

# quantidades de produtos vendidos por mês
creme_facial = np.array([ 2500, 2630, 2140, 3400, 3600, 2760, 2980, 3700, 3540, 1990, 2340, 2900 ])
limpeza_facial = np.array([ 1500, 1200, 1340, 1130, 1740, 1555, 1120, 1400, 1780, 1890, 2100, 1760 ])
pasta_dentaria = np.array([ 5200, 5100, 4550, 5870, 4560, 4890, 4780, 5860, 6100, 8300, 7300, 7400 ])
sabonete = np.array([ 9200, 6100, 9550, 8870, 7760, 7490, 8980, 9960, 8100, 10300, 13300, 14400 ])
shampoo = np.array([ 1200, 2100, 3550, 1870, 1560, 1890, 1780, 2860, 2100, 2300, 2400, 1800 ])
hidratante = np.array([ 1500, 1200, 1340, 1130, 1740, 1555, 1120, 1400, 1780, 1890, 2100, 1760 ])

# Gráfico 1 - Total de produtos Vendidos por mês - Linha
# Gráfico 2 - Gráfico com todos os produtos vendidos por mês - Linha
# Gráfico 3 - Comparativo de Creme Facial com Limpeza Facial por mês - Barras
# Gráfico 4 - Histograma de quantidade de meses (y) e faixas de quantidades de produtos vendidos (1000-1999, 2000-2999, ...)
# Gráfico 5 - Pizza. % da quantidade produtos vendidos no ano em cada produto

# %% [markdown]
# Gráfico 1 - Total de produtos Vendidos por mês - Linha

# %%
import matplotlib.pyplot as plt
import numpy as np

array = np.array([creme_facial, limpeza_facial, pasta_dentaria, sabonete, shampoo, hidratante])

fig, ax = plt.subplots()
ax.plot(mes, array.sum(axis = 0))


plt.show()

# %% [markdown]
# ### Gráfico 2 - Gráfico com todos os produtos vendidos por mês - Linha

# %%
import matplotlib.pyplot as plt
import numpy as np

abscissa = mes

fig, ax = plt.subplots()

ax.plot(abscissa, creme_facial)
ax.plot(abscissa, limpeza_facial)
ax.plot(abscissa, pasta_dentaria)
ax.plot(abscissa, sabonete)
ax.plot(abscissa, shampoo)
ax.plot(abscissa, hidratante)

plt.show()

# %% [markdown]
# ### Gráfico 3 - Comparativo de Creme Facial com Limpeza Facial por mês - Barras

# %%
import matplotlib.pyplot as plt
import numpy as np

abscissa = mes

ordenada1 = creme_facial
ordenada2 = limpeza_facial

fig, ax = plt.subplots()

largura_barra = 0.4
ax.bar(abscissa - largura_barra/2, ordenada1, largura_barra, edgecolor="white")
ax.bar(abscissa + largura_barra/2, ordenada2, largura_barra, edgecolor="black")

ax.set_xticks(abscissa)
plt.show()

# %% [markdown]
# ### Gráfico 4 - Histograma de quantidade de meses (y) e faixas de quantidades de produtos vendidos (1000-1999, 2000-2999, ...)

# %% [markdown]
# ### Gráfico 5 - Pizza. % da quantidade produtos vendidos no ano em cada produto

# %%
import matplotlib.pyplot as plt
import numpy as np

#100% = soma de todas as vendas dos produtos no ano
array = np.array([creme_facial, limpeza_facial, pasta_dentaria, sabonete, shampoo, hidratante])
print(array.sum())

#soma de venda de cada produto
somadosprodutos = [np.sum(creme_facial), np.sum(limpeza_facial), np.sum(pasta_dentaria), np.sum(sabonete), np.sum(shampoo), np.sum(hidratante)]
textos = ["Creme", "Limpeza", "Pasta", "Sabonete", "Shampoo", "Hidratante"]

fig, ax = plt.subplots()

plt.pie(somadosprodutos, labels = textos, shadow = True, autopct='%1.1f%%')
plt.show()
# Out:
# 280840
